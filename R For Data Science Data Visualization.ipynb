# %%
install.packages("tidyverse")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages(c("nycflights13", "gapminder", "Lahman"))
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
##Data Visualization
##Creating a ggplot
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
##Reusable Scatter Plot Function: ggplot(data = <DATA>) + 
  #<GEOM_FUNCTION>(mapping = aes(<MAPPINGS>))

# %%
ggplot(data = mpg)

##this part of the function just creates an empty graph
# Out:
# plot without title

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
rowsmpg <- nrow(mpg)
rowsmpg
# Out:
# [1] 234

# %%
colsmpg <- ncol(mpg)
colsmpg
# Out:
# [1] 11

# %%
?mpg
# Out:
# mpg                  package:ggplot2                   R Documentation
#
# r
#
# n:
#
#      This dataset contains a subset of the fuel economy data that the
#      EPA makes available on <URL: http://fueleconomy.gov>. It contains
#      only models which had a new release every year between 1999 and
#      2008 - this was used as a proxy for the popularity of the car.
#
# e:
#
#      mpg
#
# t:
#
#      A data frame with 234 rows and 11 variables
#
#      manufacturer
#
#      model model name
#
#      displ engine displacement, in litres
#
#      year year of manufacture
#
#      cyl number of cylinders
#
#      trans type of transmission
#
#      drv f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#      cty city miles per gallon
#
#      hwy highway miles per gallon
#
#      fl fuel type
#
#      class "type" of car

# %%
##Scatterplot of hwy v. cyl

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = cyl, y = hwy))
# Out:
# plot without title

# %%
##Scatterplot of class v. drv

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = class, y = drv))

# not useful - not enough data
# Out:
# plot without title

# %%
##Aesthetic Mapping - adds a third variable
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = class))

#scaling - assigning a unique color to each class
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, size = class))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
##alpha aesthetic - controls transparency of points
##shape aesthetic - controls shape of points

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, alpha = class))
# Out:
# Warning message:
# “Using alpha for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %%
##Setting the Aesthetic Manually

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %%
?mpg
# Out:
# mpg                  package:ggplot2                   R Documentation
#
# r
#
# n:
#
#      This dataset contains a subset of the fuel economy data that the
#      EPA makes available on <URL: http://fueleconomy.gov>. It contains
#      only models which had a new release every year between 1999 and
#      2008 - this was used as a proxy for the popularity of the car.
#
# e:
#
#      mpg
#
# t:
#
#      A data frame with 234 rows and 11 variables
#
#      manufacturer
#
#      model model name
#
#      displ engine displacement, in litres
#
#      year year of manufacture
#
#      cyl number of cylinders
#
#      trans type of transmission
#
#      drv f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#      cty city miles per gallon
#
#      hwy highway miles per gallon
#
#      fl fuel type
#
#      class "type" of car

# %%
##Categorical Variables: displ, year, cyl, trans, drv, cty, fl, class
##Continuous Variables: hwy

##Map a continuous variable by color, size, and shape
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = class, y = cty, shape = class, color = class, size = class))

#CONTINUOUS VARIABLE CANNOT BE MAPPED BY COLOR, SIZE, SHAPE
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %%
?geom_point
# Out:
# geom_point               package:ggplot2               R Documentation
#
# s
#
# n:
#
#      The point geom is used to create scatterplots. The scatterplot is
#      most useful for displaying the relationship between two continuous
#      variables. It can be used to compare one continuous and one
#      categorical variable, or two categorical variables, but a
#      variation like ‘geom_jitter()’, ‘geom_count()’, or ‘geom_bin2d()’
#      is usually more appropriate. A _bubblechart_ is a scatterplot with
#      a third variable mapped to the size of points.
#
# e:
#
#      geom_point(mapping = NULL, data = NULL, stat = "identity",
#        position = "identity", ..., na.rm = FALSE, show.legend = NA,
#        inherit.aes = TRUE)
#
# s:
#
#  mapping: Set of aesthetic mappings created by ‘aes()’ or ‘aes_()’. If
#           specified and ‘inherit.aes = TRUE’ (the default), it is
#           combined with the default mapping at the top level of the
# ...

# %%
##Stroke Aesthetic
##The stroke aesthetic seems to adjust the plotted object thickness.

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = class, y = hwy, stroke = hwy))
# Out:
# plot without title

# %%
##Mapping an Aesthetic to Something Other than Variable Name

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = class, y = hwy, colour = displ < 5))
# Out:
# plot without title

# %%
##Common Problems

#One common problem when creating ggplot2 graphics is to put the + in the wrong place: it has to come at the end of 
#the line, not the start.

#ggplot(data = mpg) 
#+ geom_point(mapping = aes(x = displ, y = hwy))

# %%
##FACETS

##faceting plot by a SINGLE VARIABLE

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)

#the variable used in facet_wrap needs to be DISCRETE
# Out:
# plot without title

# %%
##faceting by combo of TWO VARIABLES

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
##If you prefer to not facet in the rows or columns dimension, use a . instead of 
#a variable name, e.g. + facet_grid(. ~ cyl)

# %%
##Faceting on a continuous variable

##You'll get one row or column for each unique value of the variable. This can very very slow for variables that take a 
#lot of values.

# %%
##What do the empty cells in plot with facet_grid(drv ~ cyl) mean? How do they relate to this plot?

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = drv, y = cyl))

##Empty cells in `facet_grid` imply that there were no rows with that combination of values in the original dataset. This is just like in a discrete vs discrete
##scatter plot, where empty rows or columns imply that that combination of values didn't occur in the original data set.
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(drv ~ .)

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(. ~ cyl)

##`.` is just a placeholder so that we can have a facet in only one dimension.
# Out:
# plot without title
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %%
##Advantages of Faceting:It is difficult to resolve more than a dozen or so discrete colours, 
#but we can have a larger number of facets than that.

##Disadvanttages of Faceting: facets can be harder to read at a glance, or if the cells being compared aren't lined up in the 
#required dimension.

# %%
?facet_wrap
# Out:
# facet_wrap               package:ggplot2               R Documentation
#
# d
#
# n:
#
#      ‘facet_wrap’ wraps a 1d sequence of panels into 2d. This is
#      generally a better use of screen space than ‘facet_grid()’ because
#      most displays are roughly rectangular.
#
# e:
#
#      facet_wrap(facets, nrow = NULL, ncol = NULL, scales = "fixed",
#        shrink = TRUE, labeller = "label_value", as.table = TRUE,
#        switch = NULL, drop = TRUE, dir = "h", strip.position = "top")
#
# s:
#
#   facets: A set of variables or expressions quoted by ‘vars()’ and
#           defining faceting groups on the rows or columns dimension.
#           The variables can be named (the names are passed to
#           ‘labeller’).
#
#           For compatibility with the classic interface, can also be a
#           formula or character vector. Use either a one sided formula,
#           ‘~a + b’, or a character vector, ‘c("a", "b")’.
#
# nrow, ncol: Number of rows and columns.
#
# ...

# %%
##In `facet_wrap`, `nrow` and `ncol` control the numbers of rows and columns, but in `facet_grid` these are implied by the faceting variables. `dir` also controls the placement of the individual panels,
#and so isn't an argument of `facet_grid`.

# %%
### When using `facet_grid()` you should usually put the variable with more unique levels in the columns. Why?
#Most screens are wider than they are tall.

# %%
##GEOMS

#A geom is the geometrical object that a plot uses to represent data. People often describe plots by the type of geom that the plot uses. For example, bar charts use bar geoms, 
#line charts use line geoms, boxplots use boxplot geoms, and so on. Scatterplots break the trend; they use the point geom.

# %%
# left
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy))

# right
ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
##Every geom function in ggplot2 takes a mapping argument. However, not every aesthetic works with every geom. You could set the shape of a point, 
#but you couldn’t set the “shape” of a line. On the other hand, you could set the linetype of a line. geom_smooth()

# %%
ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy, linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
              
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy, group = drv))
    
ggplot(data = mpg) +
  geom_smooth(
    mapping = aes(x = displ, y = hwy, color = drv),
    show.legend = FALSE
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
##MULTIPLE GEOMS SAME PLOT

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
##ANOTHER WAY TO WRITE IT

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
##mappings for only one layer

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(color = class)) + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
##Specify different data for each layer

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(color = class)) + 
  geom_smooth(data = filter(mpg, class == "subcompact"), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
##What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?

##Line Chart:

#Boxplot:

#Histogram:

#Area Chart:

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
  geom_point() + 
  geom_smooth(se = FALSE)

##se argument: `se` specifies whether to add a translucent background showing the confidence interval.
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
##show.legend = FALSE

#It removes the legend. It gives a cleaner plot when its clear that the grouping is done on a specific variable.

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()

ggplot() + 
  geom_point(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_smooth(data = mpg, mapping = aes(x = displ, y = hwy))


##these two graphs are the same
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
#Exercise 6, Recreate the R code necessary to generate the following graphs.

##1st Two

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
    geom_point() + 
    geom_smooth(se = FALSE)

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
    geom_point() + 
    geom_smooth(aes(group = drv), se = F)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
##Second Two

ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
    geom_point() + 
    geom_smooth(aes(group = drv), se = F)

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
    geom_point(mapping = aes(color = drv)) +
    geom_smooth(se = F)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
##Third Two

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
    geom_point(mapping = aes(color = drv)) +
    geom_smooth(aes(group = drv), se = F)

ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
    geom_point(mapping = aes(color = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
##STATISTICAL TRANSFORMATIONS

ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut))

##this plots count, which is not in the raw data.

#Bar charts, histograms, and frequency polygons bin your data and then plot bin counts,
#the number of points that fall in each bin

#smoothers fit a model to your data and then plot predictions from the model.

#boxplots compute a robust summary of the distribution and then display a specially formatted box.
# Out:
# plot without title

# %%
##You can generally use geoms and stats interchangeably. For example, you can recreate the previous plot using stat_count() instead of geom_bar():

ggplot(data = diamonds) + 
  stat_count(mapping = aes(x = cut))
# Out:
# plot without title

# %%
##There are three reasons you might need to use a stat explicitly:

#1 - You might want to override the default stat.

ggplot(data = demo) +
  geom_bar(mapping = aes(x = cut, y = freq), stat = "identity")
# Out:
# Error: You're passing a function as global data.
# Have you misspelled the `data` argument in `ggplot()`
# Traceback:
#
# 1. ggplot(data = demo)
# 2. ggplot.function(data = demo)
# 3. stop("You're passing a function as global data.\nHave you misspelled the `data` argument in `ggplot()`",
#  .     call. = FALSE)

# %%
#2 - You might want to override the default mapping from transformed variables to aesthetics.

ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, y = ..prop.., group = 1))
# Out:
# plot without title

# %%
#3 - You might want to draw greater attention to the statistical transformation in your code. 

ggplot(data = diamonds) + 
  stat_summary(
    mapping = aes(x = cut, y = depth),
    fun.ymin = min,
    fun.ymax = max,
    fun.y = median
  )
# Out:
# plot without title

# %%
?stat_bin
# Out:
# geom_freqpoly             package:ggplot2              R Documentation
#
# s
#
# n:
#
#      Visualise the distribution of a single continuous variable by
#      dividing the x axis into bins and counting the number of
#      observations in each bin. Histograms (‘geom_histogram()’) display
#      the counts with bars; frequency polygons (‘geom_freqpoly()’)
#      display the counts with lines. Frequency polygons are more
#      suitable when you want to compare the distribution across the
#      levels of a categorical variable.
#
# e:
#
#      geom_freqpoly(mapping = NULL, data = NULL, stat = "bin",
#        position = "identity", ..., na.rm = FALSE, show.legend = NA,
#        inherit.aes = TRUE)
#
#      geom_histogram(mapping = NULL, data = NULL, stat = "bin",
#        position = "stack", ..., binwidth = NULL, bins = NULL,
#        na.rm = FALSE, show.legend = NA, inherit.aes = TRUE)
#
#      stat_bin(mapping = NULL, data = NULL, geom = "bar",
# ...

# %%
#Exercises

#What is the default geom associated with stat_summary()? the default geom is `geom_pointrange()`
#How could you rewrite the previous plot to use that geom function instead of the stat function?

ggplot(data = diamonds) +
  geom_pointrange(
    mapping = aes(x = cut, y = depth),
    stat = "summary"
  )
# Out:
# No summary function supplied, defaulting to `mean_se()
# plot without title

# %%
##What does geom_col() do? How is it different to geom_bar()?

#The `geom_col()` function has different default stat than `geom_bar()`.
#The default stat of `geom_col()` is `stat_identity()`, which leaves the data as is.
#The `geom_col()` function expects that the data contains `x` values and `y` values which represent the bar height.

#The default stat of `geom_bar()` is `stat_bin()`.
#The `geom_bar()` function only expects an `x` variable.
#The stat, `stat_bin()`,  preprocesses input data by counting the number of observations for each value of `x`.
#The `y` aesthetic uses the values of these counts.

# %%
##Position Adjustments

ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, colour = cut))
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = cut))
# Out:
# plot without title
# plot without title

# %%
##Clarity stacks bars

ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = clarity))
# Out:
# plot without title

# %%
##Identity

ggplot(data = diamonds, mapping = aes(x = cut, fill = clarity)) + 
  geom_bar(alpha = 1/5, position = "identity")
ggplot(data = diamonds, mapping = aes(x = cut, colour = clarity)) + 
  geom_bar(fill = NA, position = "identity")
# Out:
# plot without title
# plot without title

# %%
#Position = fill

ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "fill")
# Out:
# plot without title

# %%
##Position = Dodge

ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "dodge")
# Out:
# plot without title

# %%
#Scatterplots: Position = Jitter to avoid overplotting

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), position = "jitter")
# Out:
# plot without title

# %%
##Coordinate Systems

ggplot(data = mpg, mapping = aes(x = class, y = hwy)) + 
  geom_boxplot()
ggplot(data = mpg, mapping = aes(x = class, y = hwy)) + 
  geom_boxplot() +
  coord_flip()
# Out:
# plot without title
# plot without title

# %%
##coord_quickmap() sets the aspect ratio correctly for maps

##coord_polar() uses polar coordinates. Polar coordinates reveal an interesting connection between a bar chart and a Coxcomb chart

bar <- ggplot(data = diamonds) + 
  geom_bar(
    mapping = aes(x = cut, fill = cut), 
    show.legend = FALSE,
    width = 1
  ) + 
  theme(aspect.ratio = 1) +
  labs(x = NULL, y = NULL)

bar + coord_flip()
bar + coord_polar()
# Out:
# plot without title
# plot without title
